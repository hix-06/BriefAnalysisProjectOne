# %%
import pandas as pd
import numpy as np

# %% [markdown]
# importing the data set

# %%
myFrame = pd.read_csv(r"C:\Users\Ahmed\Downloads\xx\Salaries.csv")

# %% [markdown]
# Get a general idea about the frame,

# %%
print(myFrame.head()) #printing first few rows
print(f"num of rows are: {myFrame.shape[0]}") #get number of rows in the frame using shape[]
print(f"num of columns are: {myFrame.shape[1]}") ##get number of columns in the frame shape[]
print(myFrame.dtypes) #get fields data types to see if there is a mismatch
# Out:
#         EmployeeName                                        JobTitle  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay      Benefits   TotalPay  \
# 0  167411.18         0.00  400184.25  25010.338433  567595.43
# 1  155966.02    245131.88  137811.38  25010.338433  538909.28
# 2  212739.13    106088.18   16452.60  25010.338433  335279.91
# 3   77916.00     56120.71  198306.90  25010.338433  332343.61
# 4  134401.60      9737.00  182234.59  25010.338433  326373.19
#
#    TotalPayBenefits  Year         Agency
# 0         567595.43  2011  San Francisco
# 1         538909.28  2011  San Francisco
# 2         335279.91  2011  San Francisco
# 3         332343.61  2011  San Francisco
# 4         326373.19  2011  San Francisco
# num of rows are: 148643
# num of columns are: 10
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Agency               object
# dtype: object

# %% [markdown]
# Checking for NANs "missing values"

# %%
print(myFrame.isnull().sum()) # using the isnull() fun which return bool value, and use it with sum()..
                              # this formula returns number of missing values in each data field
# Out:
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# dtype: int64

# %% [markdown]
# a. Droping full missing data columns..

# %%
myFrame = myFrame.drop(["Notes","Status"], axis = 1) #remove both column as they has no data in them, not useful
print(f"new number of columns: {myFrame.shape[1]}")
# Out:
# new number of columns: 11

# %% [markdown]
# Give Statistical summary,

# %%
basePayMean = myFrame["BasePay"].mean()
basePayMedian = myFrame["BasePay"].median()
basePayMode = myFrame["BasePay"].mode().iloc[0] 
minBasePay = myFrame["BasePay"].min()
maxBasePay = myFrame["BasePay"].max()
basePaySTD = myFrame["BasePay"].std()

print("statistical insights:")
print(f"Mean: {basePayMean}")
print(f"Median: {basePayMedian}")
print(f"Mode: {basePayMode}")
print(f"Minimum: {minBasePay}")
print(f"Maximum: {maxBasePay}")
print(f"Standard Deviation: {basePaySTD}")
# Out:
# statistical insights:
# Mean: 66325.4488404877
# Median: 65007.45
# Mode: 0.0
# Minimum: -166.01
# Maximum: 319275.01
# Standard Deviation: 42764.63549525958

# %% [markdown]
# Note: a minimum salary turns out to be negative value
# we should handle that

# %%
negBasePayRecs = myFrame[myFrame["BasePay"] < 0]
print(f"number of negative salaries: {negBasePayRecs.shape[0]}") # see if that is a common problem
# Out:
# number of negative salaries: 11

# %% [markdown]
# Only 11 records have this data entry miss, we will remove them as they
# represent a tiny part of the data set

# %%
myFrame = myFrame.drop(negBasePayRecs.index) # remove records with negative salaries
print(f"new num of rows: {myFrame.shape[0]}")
# Out:
# new num of rows: 148643

# %%
zeroBasePayRecs = myFrame[myFrame["BasePay"] == 0]
                                                    # doing the same with zero salary values
print(f"number of emp with zero Base Salary: {zeroBasePayRecs.shape[0]}")
# Out:
# number of emp with zero Base Salary: 1298

# %% [markdown]
# I won't drop records with zero base pay as this may be due to business nature,

# %% [markdown]
# Hanling NANs "missing values",

# %%
print(myFrame.isnull().sum()) #check which fields have missingg data
# Out:
# Id                      0
# EmployeeName            0
# JobTitle                0
# BasePay               609
# OvertimePay             4
# OtherPay                4
# Benefits            36163
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# Agency                  0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer #import SimpleImputer to use it in handling NANs

# %%
nanFields = ["BasePay", "OvertimePay", "OtherPay", "Benefits"] #making a list of fileds which have NANs to deal w it,
imputer = SimpleImputer(strategy = "mean") # use the mean strategy as our fields are all numeric
myFrame[nanFields] = imputer.fit_transform(myFrame[nanFields])

# %%
print(myFrame.isnull().sum()) # checking for NANs after Handling,
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# dtype: int64

# %% [markdown]
# Visualization..

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import*

# %% [markdown]
# Histogram for salary distribution,

# %%
plt.style.use("bmh")
plt.figure(figsize = (10,6))
plt.hist(myFrame["BasePay"], histtype = "bar", bins = 50, color = '#AAD7D9', edgecolor = "black", alpha=0.5)
plt.title('Distribution of Salaries')
plt.xlabel('Base Pay')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# Pie chart for employees propotion

# %%
depCount = myFrame['JobTitle'].value_counts().head(10) # seeing all possible Job titles for the pie sections,
print(depCount)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Custodian                       2418
# TRANSIT OPERATOR                2388
# Firefighter                     2359
# Recreation Leader               1971
# Patient Care Assistant          1945
# Name: JobTitle, dtype: int64

# %%
plt.style.use("ggplot")
plt.figure(figsize=(10, 6))
colors = ['#92C7CF','#AAD7D9','#FBF9F1','#E5E1DA','#F5EEE6', '#FFF8E3', '#F3D7CA', '#E6A4B4','#FFB996','#D9EDBF']
plt.pie(depCount, labels = depCount.index, autopct = '%1.1f%%', startangle = 140, textprops = {'color': 'black'}, colors = colors)
plt.title('Proportion of Employees in Different Departments')
plt.show()

# %% [markdown]
# Grouped analysis,

# %%
print(myFrame.info()) # seeing frame full details to select a suitable field to group by it,
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148643 entries, 0 to 148653
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   EmployeeName      148643 non-null  object
#  1   JobTitle          148643 non-null  object
#  2   BasePay           148643 non-null  float64
#  3   OvertimePay       148643 non-null  float64
#  4   OtherPay          148643 non-null  float64
#  5   Benefits          148643 non-null  float64
#  6   TotalPay          148643 non-null  float64
#  7   TotalPayBenefits  148643 non-null  float64
#  8   Year              148643 non-null  int64
#  9   Agency            148643 non-null  object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 12.5+ MB
# None

# %%
myFrame = myFrame.drop(["Id"], axis = 1) # remove the id column also as it is not useful for the analysis

# %%
tBCFrame = myFrame[["JobTitle","BasePay","OvertimePay","OtherPay","Benefits","TotalPay","TotalPayBenefits"]] 
                                            # here i choosed this columns excluding object fields as
                                            # they don't suit statistical calculation
        
groupedFrame = tBCFrame.groupby("JobTitle") # use of groupby() fun to group the data by the "JobTitle" column ,

print(groupedFrame.mean())
print(groupedFrame.median())
print(groupedFrame.std())
                            # diong grouped statistical overview,
print(groupedFrame.min())
print(groupedFrame.max())
print(groupedFrame.sum())
print(groupedFrame.count())

avgBaseSal = groupedFrame["BasePay"].mean() #comparing the average salary across different groups,
print(avgBaseSal)
# Out:
#                                                      BasePay  OvertimePay  \
# JobTitle
# ACCOUNT CLERK                                   43300.806506   373.200843
# ACCOUNTANT                                      46643.172000     0.000000
# ACCOUNTANT INTERN                               28732.663958    24.430625
# ACPO,JuvP, Juv Prob (SFERS)                     62290.780000     0.000000
# ACUPUNCTURIST                                   66374.400000     0.000000
# ...                                                      ...          ...
# X-RAY LABORATORY AIDE                           47664.773077  3571.223462
# X-Ray Laboratory Aide                           46086.387100  3483.767100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  52609.910000     0.000000
# Youth Comm Advisor                              39077.957500     0.000000
# ZOO CURATOR                                     43148.000000     0.000000
#
#                                                     OtherPay      Benefits  \
# JobTitle
# ACCOUNT CLERK                                     361.656988  25010.338433
# ACCOUNTANT                                        786.096000  25010.338433
# ACCOUNTANT INTERN                                 274.648333  25010.338433
# ACPO,JuvP, Juv Prob (SFERS)                         0.000000  17975.590000
# ACUPUNCTURIST                                    1220.000000  25010.338433
# ...                                                      ...           ...
# X-RAY LABORATORY AIDE                            1469.883846  25010.338433
# X-Ray Laboratory Aide                            1253.788500  18697.180500
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS   1022.960000  25010.338433
# Youth Comm Advisor                               2336.350000  18704.242500
# ZOO CURATOR                                     23538.560000  25010.338433
#
#                                                     TotalPay  TotalPayBenefits
# JobTitle
# ACCOUNT CLERK                                   44035.664337      44035.664337
# ACCOUNTANT                                      47429.268000      47429.268000
# ACCOUNTANT INTERN                               29031.742917      29031.742917
# ACPO,JuvP, Juv Prob (SFERS)                     62290.780000      80266.370000
# ACUPUNCTURIST                                   67594.400000      67594.400000
# ...                                                      ...               ...
# X-RAY LABORATORY AIDE                           52705.880385      52705.880385
# X-Ray Laboratory Aide                           50823.942700      69521.123200
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  53632.870000      53632.870000
# Youth Comm Advisor                              41414.307500      60118.550000
# ZOO CURATOR                                     66686.560000      66686.560000
#
# [2159 rows x 6 columns]
#                                                   BasePay  OvertimePay  \
# JobTitle
# ACCOUNT CLERK                                   49777.780        0.000
# ACCOUNTANT                                      60076.240        0.000
# ACCOUNTANT INTERN                               16806.755        0.000
# ACPO,JuvP, Juv Prob (SFERS)                     62290.780        0.000
# ACUPUNCTURIST                                   66374.400        0.000
# ...                                                   ...          ...
# X-RAY LABORATORY AIDE                           54066.080     2471.100
# X-Ray Laboratory Aide                           55251.635      941.215
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  52609.910        0.000
# Youth Comm Advisor                              42425.650        0.000
# ZOO CURATOR                                     43148.000        0.000
#
#                                                  OtherPay      Benefits  \
# JobTitle
# ACCOUNT CLERK                                       0.000  25010.338433
# ACCOUNTANT                                          0.000  25010.338433
# ACCOUNTANT INTERN                                   0.000  25010.338433
# ACPO,JuvP, Juv Prob (SFERS)                         0.000  17975.590000
# ACUPUNCTURIST                                    1220.000  25010.338433
# ...                                                   ...           ...
# X-RAY LABORATORY AIDE                             833.150  25010.338433
# X-Ray Laboratory Aide                             801.895  26107.200000
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS   1022.960  25010.338433
# Youth Comm Advisor                               2024.245  20421.390000
# ZOO CURATOR                                     23538.560  25010.338433
#
#                                                  TotalPay  TotalPayBenefits
# JobTitle
# ACCOUNT CLERK                                   49777.820         49777.820
# ACCOUNTANT                                      60076.240         60076.240
# ACCOUNTANT INTERN                               17658.505         17658.505
# ACPO,JuvP, Juv Prob (SFERS)                     62290.780         80266.370
# ACUPUNCTURIST                                   67594.400         67594.400
# ...                                                   ...               ...
# X-RAY LABORATORY AIDE                           60333.125         60333.125
# X-Ray Laboratory Aide                           60047.290         85551.190
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  53632.870         53632.870
# Youth Comm Advisor                              44449.895         64871.285
# ZOO CURATOR                                     66686.560         66686.560
#
# [2159 rows x 6 columns]
#                                                      BasePay  OvertimePay  \
# JobTitle
# ACCOUNT CLERK                                   12890.631740  1400.408714
# ACCOUNTANT                                      27703.019579     0.000000
# ACCOUNTANT INTERN                               20635.668379   118.671160
# ACPO,JuvP, Juv Prob (SFERS)                              NaN          NaN
# ACUPUNCTURIST                                            NaN          NaN
# ...                                                      ...          ...
# X-RAY LABORATORY AIDE                           17300.039056  4858.619801
# X-Ray Laboratory Aide                           20467.891506  6458.223654
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS           NaN          NaN
# Youth Comm Advisor                              19974.143972     0.000000
# ZOO CURATOR                                              NaN          NaN
#
#                                                    OtherPay      Benefits  \
# JobTitle
# ACCOUNT CLERK                                    576.172993      0.000000
# ACCOUNTANT                                      1221.582691      0.000000
# ACCOUNTANT INTERN                                788.004565      0.000000
# ACPO,JuvP, Juv Prob (SFERS)                             NaN           NaN
# ACUPUNCTURIST                                           NaN           NaN
# ...                                                     ...           ...
# X-RAY LABORATORY AIDE                           1594.230668      0.000000
# X-Ray Laboratory Aide                           1618.323419  12122.842263
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS          NaN           NaN
# Youth Comm Advisor                              2745.505511  10200.291093
# ZOO CURATOR                                             NaN           NaN
#
#                                                     TotalPay  TotalPayBenefits
# JobTitle
# ACCOUNT CLERK                                   13170.742908      13170.742908
# ACCOUNTANT                                      27137.331315      27137.331315
# ACCOUNTANT INTERN                               20711.322649      20711.322649
# ACPO,JuvP, Juv Prob (SFERS)                              NaN               NaN
# ACUPUNCTURIST                                            NaN               NaN
# ...                                                      ...               ...
# X-RAY LABORATORY AIDE                           19760.943417      19760.943417
# X-Ray Laboratory Aide                           24170.083004      35747.544961
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS           NaN               NaN
# Youth Comm Advisor                              17311.066571      27510.488387
# ZOO CURATOR                                              NaN               NaN
#
# [2159 rows x 6 columns]
#                                                  BasePay  OvertimePay  \
# JobTitle
# ACCOUNT CLERK                                     614.00          0.0
# ACCOUNTANT                                          0.00          0.0
# ACCOUNTANT INTERN                                2981.53          0.0
# ACPO,JuvP, Juv Prob (SFERS)                     62290.78          0.0
# ACUPUNCTURIST                                   66374.40          0.0
# ...                                                  ...          ...
# X-RAY LABORATORY AIDE                            4690.68          0.0
# X-Ray Laboratory Aide                            1007.00          0.0
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  52609.91          0.0
# Youth Comm Advisor                              13915.80          0.0
# ZOO CURATOR                                     43148.00          0.0
#
#                                                 OtherPay      Benefits  \
# JobTitle
# ACCOUNT CLERK                                       0.00  25010.338433
# ACCOUNTANT                                          0.00  25010.338433
# ACCOUNTANT INTERN                                   0.00  25010.338433
# ACPO,JuvP, Juv Prob (SFERS)                         0.00  17975.590000
# ACUPUNCTURIST                                    1220.00  25010.338433
# ...                                                  ...           ...
# X-RAY LABORATORY AIDE                             200.00  25010.338433
# X-Ray Laboratory Aide                               0.00     10.070000
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS   1022.96  25010.338433
# Youth Comm Advisor                                  0.00   5744.530000
# ZOO CURATOR                                     23538.56  25010.338433
#
#                                                 TotalPay  TotalPayBenefits
# JobTitle
# ACCOUNT CLERK                                     614.00            614.00
# ACCOUNTANT                                       1148.40           1148.40
# ACCOUNTANT INTERN                                2981.53           2981.53
# ACPO,JuvP, Juv Prob (SFERS)                     62290.78          80266.37
# ACUPUNCTURIST                                   67594.40          67594.40
# ...                                                  ...               ...
# X-RAY LABORATORY AIDE                            5343.69           5343.69
# X-Ray Laboratory Aide                            1007.00           1017.07
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  53632.87          53632.87
# Youth Comm Advisor                              19212.71          24957.24
# ZOO CURATOR                                     66686.56          66686.56
#
# [2159 rows x 6 columns]
#                                                  BasePay  OvertimePay  \
# JobTitle
# ACCOUNT CLERK                                   60838.20     10753.06
# ACCOUNTANT                                      65392.01         0.00
# ACCOUNTANT INTERN                               58501.72       624.84
# ACPO,JuvP, Juv Prob (SFERS)                     62290.78         0.00
# ACUPUNCTURIST                                   66374.40         0.00
# ...                                                  ...          ...
# X-RAY LABORATORY AIDE                           60086.62     23016.22
# X-Ray Laboratory Aide                           66123.01     29239.96
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  52609.91         0.00
# Youth Comm Advisor                              57544.73         0.00
# ZOO CURATOR                                     43148.00         0.00
#
#                                                 OtherPay      Benefits  \
# JobTitle
# ACCOUNT CLERK                                    3370.13  25010.338433
# ACCOUNTANT                                       2782.08  25010.338433
# ACCOUNTANT INTERN                                3069.19  25010.338433
# ACPO,JuvP, Juv Prob (SFERS)                         0.00  17975.590000
# ACUPUNCTURIST                                    1220.00  25010.338433
# ...                                                  ...           ...
# X-RAY LABORATORY AIDE                            5643.93  25010.338433
# X-Ray Laboratory Aide                            7916.20  32234.860000
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS   1022.96  25010.338433
# Youth Comm Advisor                               5296.91  28229.660000
# ZOO CURATOR                                     23538.56  25010.338433
#
#                                                 TotalPay  TotalPayBenefits
# JobTitle
# ACCOUNT CLERK                                   60838.20          60838.20
# ACCOUNTANT                                      65392.01          65392.01
# ACCOUNTANT INTERN                               58799.53          58799.53
# ACPO,JuvP, Juv Prob (SFERS)                     62290.78          80266.37
# ACUPUNCTURIST                                   67594.40          67594.40
# ...                                                  ...               ...
# X-RAY LABORATORY AIDE                           85077.40          85077.40
# X-Ray Laboratory Aide                           99812.97         129044.16
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  53632.87          53632.87
# Youth Comm Advisor                              57544.73          85774.39
# ZOO CURATOR                                     66686.56          66686.56
#
# [2159 rows x 6 columns]
#                                                    BasePay  OvertimePay  \
# JobTitle
# ACCOUNT CLERK                                   3593966.94     30975.67
# ACCOUNTANT                                       233215.86         0.00
# ACCOUNTANT INTERN                               1379167.87      1172.67
# ACPO,JuvP, Juv Prob (SFERS)                       62290.78         0.00
# ACUPUNCTURIST                                     66374.40         0.00
# ...                                                    ...          ...
# X-RAY LABORATORY AIDE                           1239284.10     92851.81
# X-Ray Laboratory Aide                           4608638.71    348376.71
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.91         0.00
# Youth Comm Advisor                               156311.83         0.00
# ZOO CURATOR                                       43148.00         0.00
#
#                                                  OtherPay      Benefits  \
# JobTitle
# ACCOUNT CLERK                                    30017.53  2.075858e+06
# ACCOUNTANT                                        3930.48  1.250517e+05
# ACCOUNTANT INTERN                                13183.12  1.200496e+06
# ACPO,JuvP, Juv Prob (SFERS)                          0.00  1.797559e+04
# ACUPUNCTURIST                                     1220.00  2.501034e+04
# ...                                                   ...           ...
# X-RAY LABORATORY AIDE                            38216.98  6.502688e+05
# X-Ray Laboratory Aide                           125378.85  1.869718e+06
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    1022.96  2.501034e+04
# Youth Comm Advisor                                9345.40  7.481697e+04
# ZOO CURATOR                                      23538.56  2.501034e+04
#
#                                                   TotalPay  TotalPayBenefits
# JobTitle
# ACCOUNT CLERK                                   3654960.14        3654960.14
# ACCOUNTANT                                       237146.34         237146.34
# ACCOUNTANT INTERN                               1393523.66        1393523.66
# ACPO,JuvP, Juv Prob (SFERS)                       62290.78          80266.37
# ACUPUNCTURIST                                     67594.40          67594.40
# ...                                                    ...               ...
# X-RAY LABORATORY AIDE                           1370352.89        1370352.89
# X-Ray Laboratory Aide                           5082394.27        6952112.32
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    53632.87          53632.87
# Youth Comm Advisor                               165657.23         240474.20
# ZOO CURATOR                                       66686.56          66686.56
#
# [2159 rows x 6 columns]
#                                                 BasePay  OvertimePay  \
# JobTitle
# ACCOUNT CLERK                                        83           83
# ACCOUNTANT                                            5            5
# ACCOUNTANT INTERN                                    48           48
# ACPO,JuvP, Juv Prob (SFERS)                           1            1
# ACUPUNCTURIST                                         1            1
# ...                                                 ...          ...
# X-RAY LABORATORY AIDE                                26           26
# X-Ray Laboratory Aide                               100          100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS        1            1
# Youth Comm Advisor                                    4            4
# ZOO CURATOR                                           1            1
#
#                                                 OtherPay  Benefits  TotalPay  \
# JobTitle
# ACCOUNT CLERK                                         83        83        83
# ACCOUNTANT                                             5         5         5
# ACCOUNTANT INTERN                                     48        48        48
# ACPO,JuvP, Juv Prob (SFERS)                            1         1         1
# ACUPUNCTURIST                                          1         1         1
# ...                                                  ...       ...       ...
# X-RAY LABORATORY AIDE                                 26        26        26
# X-Ray Laboratory Aide                                100       100       100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS         1         1         1
# Youth Comm Advisor                                     4         4         4
# ZOO CURATOR                                            1         1         1
#
#                                                 TotalPayBenefits
# JobTitle
# ACCOUNT CLERK                                                 83
# ACCOUNTANT                                                     5
# ACCOUNTANT INTERN                                             48
# ACPO,JuvP, Juv Prob (SFERS)                                    1
# ACUPUNCTURIST                                                  1
# ...                                                          ...
# X-RAY LABORATORY AIDE                                         26
# X-Ray Laboratory Aide                                        100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS                 1
# Youth Comm Advisor                                             4
# ZOO CURATOR                                                    1
#
# [2159 rows x 6 columns]
# JobTitle
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     66374.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             47664.773077
# X-Ray Laboratory Aide                             46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# Youth Comm Advisor                                39077.957500
# ZOO CURATOR                                       43148.000000
# Name: BasePay, Length: 2159, dtype: float64

# %%
print(myFrame.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148643 entries, 0 to 148653
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   EmployeeName      148643 non-null  object
#  1   JobTitle          148643 non-null  object
#  2   BasePay           148643 non-null  float64
#  3   OvertimePay       148643 non-null  float64
#  4   OtherPay          148643 non-null  float64
#  5   Benefits          148643 non-null  float64
#  6   TotalPay          148643 non-null  float64
#  7   TotalPayBenefits  148643 non-null  float64
#  8   Year              148643 non-null  int64
#  9   Agency            148643 non-null  object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 12.5+ MB
# None

# %% [markdown]
# Simple correlation analysis,

# %%
import seaborn as sns

# %%
correlation = myFrame['BasePay'].corr(myFrame['TotalPay']) # identify correlation between BasePay and TotalPay columns,
print("Correlation between 'BasePay' and 'TotalPay'is :",correlation)
# Out:
# Correlation between 'BasePay' and 'TotalPay'is : 0.9505054094571114

# %% [markdown]
# Gives a strong positive correaltion, means they hard related to eachother,

# %% [markdown]
# Visualizing correlation with Scatter plot

# %%
plt.style.use("ggplot")
plt.figure(figsize=(8, 6))
plt.scatter(myFrame['BasePay'], myFrame['TotalPay'], color='blue', alpha=0.7)
plt.title('Scatter Plot - BasePay vs TotalPay')
plt.xlabel('BasePay')
plt.ylabel('TotalPay')
plt.grid(True)
plt.show()

# %% [markdown]
# Give a full correlation Overview,

# %%
fCFrame = myFrame.select_dtypes(exclude = "object") #get only numeric fields for corr calculation
c = fCFrame.corr()
print(c)
# Out:
#                    BasePay  OvertimePay  OtherPay  Benefits  TotalPay  \
# BasePay           1.000000     0.266609  0.283735  0.806623  0.950505
# OvertimePay       0.266609     1.000000  0.316582  0.268514  0.504841
# OtherPay          0.283735     0.316582  1.000000  0.203586  0.470474
# Benefits          0.806623     0.268514  0.203586  1.000000  0.782644
# TotalPay          0.950505     0.504841  0.470474  0.782644  1.000000
# TotalPayBenefits  0.942988     0.467961  0.422316  0.842996  0.977309
# Year              0.033687     0.027872 -0.002515 -0.027522  0.032042
#
#                   TotalPayBenefits      Year
# BasePay                   0.942988  0.033687
# OvertimePay               0.467961  0.027872
# OtherPay                  0.422316 -0.002515
# Benefits                  0.842996 -0.027522
# TotalPay                  0.977309  0.032042
# TotalPayBenefits          1.000000  0.151909
# Year                      0.151909  1.000000

# %% [markdown]
# Visualize the correlation information with a heat map ,

# %%
sns.heatmap(c, annot = True) # use heatmap() fun and pass corr as parameter to visualize it
# Out:
# <Axes: >

# %%
print(myFrame.head(10)) # final look at the frame
# Out:
#          EmployeeName                                        JobTitle  \
# 0      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay      Benefits   TotalPay  \
# 0  167411.18         0.00  400184.25  25010.338433  567595.43
# 1  155966.02    245131.88  137811.38  25010.338433  538909.28
# 2  212739.13    106088.18   16452.60  25010.338433  335279.91
# 3   77916.00     56120.71  198306.90  25010.338433  332343.61
# 4  134401.60      9737.00  182234.59  25010.338433  326373.19
# 5  118602.00      8601.00  189082.74  25010.338433  316285.74
# 6   92492.01     89062.90  134426.14  25010.338433  315981.05
# 7  256576.96         0.00   51322.50  25010.338433  307899.46
# 8  176932.64     86362.68   40132.23  25010.338433  303427.55
# 9  285262.00         0.00   17115.73  25010.338433  302377.73
#
#    TotalPayBenefits  Year         Agency
# 0         567595.43  2011  San Francisco
# 1         538909.28  2011  San Francisco
# 2         335279.91  2011  San Francisco
# 3         332343.61  2011  San Francisco
# 4         326373.19  2011  San Francisco
# 5         316285.74  2011  San Francisco
# 6         315981.05  2011  San Francisco
# 7         307899.46  2011  San Francisco
# 8         303427.55  2011  San Francisco
# 9         302377.73  2011  San Francisco

# %% [markdown]
# Summary Insights Report: Analysis of Employee Salary Data:
#
# 1. Data Overview:
#    - The dataset consists of employee information with 13 columns, including details such as employee name, job title, base pay, overtime pay, benefits, and more.
#    - The initial dataset contained 148,654 rows and 13 columns.
#
# 2. Data Cleaning:
#    - Two columns, "Notes" and "Status," were dropped as they contained null values and were not relevant for analysis.
#    - Negative base salaries (if any) were identified, and the corresponding records were removed.
#    - Missing values in numeric fields (BasePay, OvertimePay, OtherPay, Benefits) were imputed using the mean value.
#
# 3. Statistical Insights:
#    - Descriptive statistics for the "BasePay" column were calculated, including mean, median, mode, minimum, maximum, and standard deviation.
#    - Identified and removed records with negative base pay.
#    - Explored the distribution of salaries through a histogram.
#
# 4. Job Title Analysis:
#    - Explored the top 10 most frequent job titles and visualized their proportions using a pie chart.
#    - Grouped the data by job title and calculated mean, median, standard deviation, minimum, maximum, sum, and count for relevant numeric columns.
#
# 5. Correlation Analysis:
#    - Calculated the correlation between "BasePay" and "TotalPay" and visualized it using a scatter plot.
#    - Utilized a heatmap to display the correlation matrix for all numeric features.
#
# 6. Visualization:
#    - Utilized various plots (histogram, pie chart, scatter plot, heatmap) to provide a comprehensive visual representation of the data.
#
# 7. Key Findings:
#    - The dataset contains a diverse range of job titles with varying salary distributions.
#    - The correlation between "BasePay" and "TotalPay" indicates a positive relationship.
#    - Data imputation was necessary to handle missing values in relevant columns.
#
# 8. Recommendations:
#    - Further exploration and analysis can be conducted on specific job titles or departments.
#    - Consideration of additional factors (e.g., years of service, education level) for a more comprehensive analysis.
#
# 9. Conclusion:
#    - The analysis provides valuable insights into the salary distribution, job titles, and relationships between key variables in the dataset. These insights can inform decision-making processes and future analyses.
#
# This summary report highlights the key steps, findings, and visualizations from the analysis of the employee salary dataset.
